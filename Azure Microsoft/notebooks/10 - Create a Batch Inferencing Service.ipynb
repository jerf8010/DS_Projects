# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.38.0 to work with fitta-project

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8896666666666667
# AUC: 0.8746579431812528
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_ds_b01 - Default = False
# azureml_globaldatasets - Default = False
# workspaceartifactstore - Default = False
# workspaceworkingdirectory - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# Folder created!
# Saving files...
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 44 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 45 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 46 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 47 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 48 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 49 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "your-compute-cluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [db8fc392][4861cc92-c165-4083-9b8d-b94debf7de4f], (This step will run and generate new outputs)
# Submitted PipelineRun 4d3bc33b-0b37-4a97-801c-9a012ebfe59c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4d3bc33b-0b37-4a97-801c-9a012ebfe59c?wsid=/subscriptions/f0ec0447-a406-4c0a-922d-f468c99bce13/resourcegroups/defaultresourcegroup-usw3/workspaces/fitta-project&tid=f94bf4d9-8097-4794-adf6-a5466ca28563
# PipelineRunId: 4d3bc33b-0b37-4a97-801c-9a012ebfe59c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4d3bc33b-0b37-4a97-801c-9a012ebfe59c?wsid=/subscriptions/f0ec0447-a406-4c0a-922d-f468c99bce13/resourcegroups/defaultresourcegroup-usw3/workspaces/fitta-project&tid=f94bf4d9-8097-4794-adf6-a5466ca28563
# PipelineRun Status: Running
#
#
# StepRunId: 88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a?wsid=/subscriptions/f0ec0447-a406-4c0a-922d-f468c99bce13/resourcegroups/defaultresourcegroup-usw3/workspaces/fitta-project&tid=f94bf4d9-8097-4794-adf6-a5466ca28563
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/03/12 08:24:30 Downloading source code...
# 2022/03/12 08:24:31 Finished downloading source code
# 2022/03/12 08:24:31 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/03/12 08:24:31 Successfully set up Docker network: acb_default_network
# 2022/03/12 08:24:31 Setting up Docker configuration...
# 2022/03/12 08:24:32 Successfully set up Docker configuration
# 2022/03/12 08:24:32 Logging in to registry: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io
# 2022/03/12 08:24:33 Successfully logged into b7697f56f94b4e839c4e46b96d210dcb.azurecr.io
# 2022/03/12 08:24:33 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/03/12 08:24:33 Scanning for dependencies...
# 2022/03/12 08:24:33 Successfully scanned dependencies
# 2022/03/12 08:24:33 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1@sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1@sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 2f94e549220a: Already exists
# 2b2d92136c10: Pulling fs layer
# 0b412d2669ed: Pulling fs layer
# 805003cfcee6: Pulling fs layer
# ad877dc53455: Pulling fs layer
# afa783568628: Pulling fs layer
# d67cf86adb17: Pulling fs layer
# 82770c3b2808: Pulling fs layer
# c991e53ceb53: Pulling fs layer
# ad877dc53455: Waiting
# afa783568628: Waiting
# d67cf86adb17: Waiting
# 82770c3b2808: Waiting
# c991e53ceb53: Waiting
# 805003cfcee6: Verifying Checksum
# 805003cfcee6: Download complete
# ad877dc53455: Verifying Checksum
# ad877dc53455: Download complete
# afa783568628: Verifying Checksum
# afa783568628: Download complete
# 2b2d92136c10: Verifying Checksum
# 2b2d92136c10: Download complete
# d67cf86adb17: Verifying Checksum
# d67cf86adb17: Download complete
# 82770c3b2808: Verifying Checksum
# 82770c3b2808: Download complete
# 0b412d2669ed: Verifying Checksum
# 0b412d2669ed: Download complete
# c991e53ceb53: Verifying Checksum
# c991e53ceb53: Download complete
# 2b2d92136c10: Pull complete
# 0b412d2669ed: Pull complete
# 805003cfcee6: Pull complete
# ad877dc53455: Pull complete
# afa783568628: Pull complete
# d67cf86adb17: Pull complete
# 82770c3b2808: Pull complete
# c991e53ceb53: Pull complete
# Digest: sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1@sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
#  ---> 54296612fc48
# Step 2/21 : USER root
#  ---> Running in 4f6834fb22af
# Removing intermediate container 4f6834fb22af
#  ---> e202e8def98e
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in b9cfaac0b446
# Removing intermediate container b9cfaac0b446
#  ---> 8d92e7470f08
# Step 4/21 : WORKDIR /
#  ---> Running in 636a938ba70c
# Removing intermediate container 636a938ba70c
#  ---> 31b7135afe00
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 192a39b233bd
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in aa9590a62ff6
# Removing intermediate container aa9590a62ff6
#  ---> 3a8e6b401825
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 088e759b4713
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in d5cc0e4e1e79
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ########1  |  82%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | #######1   |  71%
# python-3.6.2         | 23.6 MB   | ########## | 100%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | #          |  11%
# mkl-2020.2           | 138.3 MB  | ##5        |  26%
# mkl-2020.2           | 138.3 MB  | ####       |  40%
# mkl-2020.2           | 138.3 MB  | #####4     |  55%
# mkl-2020.2           | 138.3 MB  | ######7    |  68%
# mkl-2020.2           | 138.3 MB  | ########2  |  83%
# mkl-2020.2           | 138.3 MB  | #########7 |  97%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# intel-openmp-2022.0. | 4.2 MB    |            |   0%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# ca-certificates-2022 | 122 KB    |            |   0%
# ca-certificates-2022 | 122 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# zlib-1.2.11          | 108 KB    |            |   0%
# zlib-1.2.11          | 108 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.qcw5ld4o.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.39.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-core~=1.39.0
#   Downloading azureml_core-1.39.0-py3-none-any.whl (2.5 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.39.0
#   Downloading azureml_dataset_runtime-1.39.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.10-py3-none-any.whl (38 kB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
# Collecting pytz
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.10.1-py2.py3-none-any.whl (211 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<1.22
#   Downloading azure_core-1.21.1-py2.py3-none-any.whl (178 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting azure-mgmt-containerregistry<9.0.0,>=8.2.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyopenssl<22.0.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.1.0-py3-none-any.whl (1.8 MB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.17.0-py2.py3-none-any.whl (79 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Collecting argcomplete<2.0
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
# Collecting azure-mgmt-resource<21.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-20.1.0-py3-none-any.whl (2.3 MB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<1.22->azureml-core~=1.39.0->azureml-defaults->-r /azureml-environment-setup/condaenv.qcw5ld4o.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azureml-dataprep<2.28.0a,>=2.27.1a
#   Downloading azureml_dataprep-2.27.1-py3-none-any.whl (39.4 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.39.0->azureml-defaults->-r /azureml-environment-setup/condaenv.qcw5ld4o.requirements.txt (line 1)) (1.19.2)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.23-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-rslex~=2.3.0dev0
#   Downloading azureml_dataprep_rslex-2.3.1-cp36-cp36m-manylinux1_x86_64.whl (13.6 MB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting itsdangerous<2.0,>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.qcw5ld4o.requirements.txt (line 1)) (58.0.4)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting pygments
#   Downloading Pygments-2.11.2-py3-none-any.whl (1.1 MB)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.39.0->azureml-defaults->-r /azureml-environment-setup/condaenv.qcw5ld4o.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=9303deeaa1097ab913e111a840f22c9ae6d69bbc28eac3bea9edc821a3cd1c23
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=aa2fb5ed2de43445c479ad1055289ff280a794e5926b4e41be86e22b4c16b22c
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69943 sha256=748a9e62323a5fe0a1af57cf54fb85571edf9b6a07d95264ad61742b1bf8e456
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, portalocker, oauthlib, msal, zipp, typing-extensions, requests-oauthlib, python-dateutil, msal-extensions, isodate, distro, azure-core, msrest, MarkupSafe, importlib-metadata, dotnetcore2, dataclasses, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, Werkzeug, websocket-client, tabulate, pyyaml, pytz, PySocks, pyparsing, pyopenssl, pynacl, pygments, pyasn1, pyarrow, msrestazure, jmespath, Jinja2, jeepney, itsdangerous, click, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 PySocks-1.7.1 SecretStorage-3.3.1 Werkzeug-2.0.3 adal-1.2.7 applicationinsights-0.11.10 argcomplete-1.12.3 azure-common-1.1.28 azure-core-1.21.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-20.1.0 azure-mgmt-storage-19.1.0 azureml-core-1.39.0 azureml-dataprep-2.27.1 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.3.1 azureml-dataset-runtime-1.39.0 azureml-defaults-1.39.0 azureml-inference-server-http-0.4.10 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 cffi-1.15.0 charset-normalizer-2.0.12 click-8.0.4 cloudpickle-2.0.0 configparser-3.7.4 contextlib2-21.6.0 cryptography-36.0.1 dataclasses-0.8 distro-1.7.0 docker-5.0.3 dotnetcore2-2.1.23 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 humanfriendly-10.0 idna-3.3 importlib-metadata-4.8.3 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-1.1.0 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.1.0 knack-0.9.0 msal-1.17.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.0 packaging-21.3 paramiko-2.10.1 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.4.0 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.21 pygments-2.11.2 pynacl-1.5.0 pyopenssl-21.0.0 pyparsing-3.0.7 python-dateutil-2.8.2 pytz-2021.3 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 tabulate-0.8.9 typing-extensions-4.1.1 urllib3-1.26.7 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container d5cc0e4e1e79
#  ---> 64f7117e340a
# Step 9/21 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in 9cddac97eee6
# Removing intermediate container 9cddac97eee6
#  ---> fc193100f527
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> ae16bf8bfe17
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 0b77a373c676
# Copying environment context
# Removing intermediate container 0b77a373c676
#  ---> e977fb745e88
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> ff7dc78cc7b7
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 91187a60a04d
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 91187a60a04d
#  ---> 41f4afa26734
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in abbf32d79a9f
# Removing intermediate container abbf32d79a9f
#  ---> 6cd90190982c
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in bffadcf6df00
# Removing intermediate container bffadcf6df00
#  ---> 029dc4b4516b
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_e220b045f6c3c3008b1a386af067185d CONDA_PREFIX=/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 3eb4626f7f36
# Removing intermediate container 3eb4626f7f36
#  ---> ebc085388a0e
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> a046d973604c
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in b6afffbd2d62
# Removing intermediate container b6afffbd2d62
#  ---> 8ebbc1b74c7c
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 5512bd8ef4f9
# Removing intermediate container 5512bd8ef4f9
#  ---> 4020437739b8
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 772299f0dcaf
# Removing intermediate container 772299f0dcaf
#  ---> d3506bbe0fe1
# Step 21/21 : CMD ["bash"]
#  ---> Running in 0135935d98b1
# Removing intermediate container 0135935d98b1
#  ---> a580073a3c42
# Successfully built a580073a3c42
# Successfully tagged b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2:latest
# Successfully tagged b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2:1
# 2022/03/12 08:26:17 Successfully executed container: acb_step_0
# 2022/03/12 08:26:17 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/03/12 08:26:17 Pushing image: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2:1, attempt 1
# The push refers to repository [b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2]
# ed4d72bdcf12: Preparing
# b68095f82f73: Preparing
# 550a044cdda8: Preparing
# 2556c023022a: Preparing
# 48d71979ab74: Preparing
# bd36b503ba11: Preparing
# ebfd6e54712b: Preparing
# 7f6ab6b2bf40: Preparing
# 91b863d74e84: Preparing
# 1d01cf03dc29: Preparing
# 5a63f0a64b99: Preparing
# cfd97667b73b: Preparing
# dda643f89a6b: Preparing
# 06f4d263b25f: Preparing
# 5ecae586bbba: Preparing
# eb66e810a3df: Preparing
# 081c0f822cac: Preparing
# 0be4c2d28ad7: Preparing
# 40a154bd3352: Preparing
# bd36b503ba11: Waiting
# ebfd6e54712b: Waiting
# 7f6ab6b2bf40: Waiting
# 91b863d74e84: Waiting
# 1d01cf03dc29: Waiting
# 5a63f0a64b99: Waiting
# cfd97667b73b: Waiting
# dda643f89a6b: Waiting
# 06f4d263b25f: Waiting
# 5ecae586bbba: Waiting
# 40a154bd3352: Waiting
# 081c0f822cac: Waiting
# eb66e810a3df: Waiting
# 0be4c2d28ad7: Waiting
# 48d71979ab74: Pushed
# 2556c023022a: Pushed
# ed4d72bdcf12: Pushed
# b68095f82f73: Pushed
# 550a044cdda8: Pushed
# ebfd6e54712b: Pushed
# 91b863d74e84: Pushed
# 7f6ab6b2bf40: Pushed
# 1d01cf03dc29: Pushed
# 5a63f0a64b99: Pushed
# cfd97667b73b: Pushed
# dda643f89a6b: Pushed
# 06f4d263b25f: Pushed
# 081c0f822cac: Pushed
# eb66e810a3df: Pushed
# 5ecae586bbba: Pushed
# 0be4c2d28ad7: Pushed
# 40a154bd3352: Pushed
#
# bd36b503ba11: Pushed
# 1: digest: sha256:f305c305b99c459ccd9a17f2a6a454150649fa9241ea9ee2a9f2751e6a5d9106 size: 4307
# 2022/03/12 08:27:54 Successfully pushed image: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2:1
# 2022/03/12 08:27:54 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/03/12 08:27:54 Pushing image: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2:latest, attempt 1
# The push refers to repository [b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2]
# ed4d72bdcf12: Preparing
# b68095f82f73: Preparing
# 550a044cdda8: Preparing
# 2556c023022a: Preparing
# 48d71979ab74: Preparing
# bd36b503ba11: Preparing
# ebfd6e54712b: Preparing
# 7f6ab6b2bf40: Preparing
# 91b863d74e84: Preparing
# 1d01cf03dc29: Preparing
# 5a63f0a64b99: Preparing
# cfd97667b73b: Preparing
# dda643f89a6b: Preparing
# 06f4d263b25f: Preparing
# 5ecae586bbba: Preparing
# eb66e810a3df: Preparing
# 081c0f822cac: Preparing
# 0be4c2d28ad7: Preparing
# 40a154bd3352: Preparing
# bd36b503ba11: Waiting
# ebfd6e54712b: Waiting
# 7f6ab6b2bf40: Waiting
# 06f4d263b25f: Waiting
# 5ecae586bbba: Waiting
# 91b863d74e84: Waiting
# eb66e810a3df: Waiting
# 1d01cf03dc29: Waiting
# 5a63f0a64b99: Waiting
# 081c0f822cac: Waiting
# 0be4c2d28ad7: Waiting
# cfd97667b73b: Waiting
# dda643f89a6b: Waiting
# 40a154bd3352: Waiting
# ed4d72bdcf12: Layer already exists
# 550a044cdda8: Layer already exists
# 48d71979ab74: Layer already exists
# 2556c023022a: Layer already exists
# b68095f82f73: Layer already exists
# 7f6ab6b2bf40: Layer already exists
# bd36b503ba11: Layer already exists
# 1d01cf03dc29: Layer already exists
# 91b863d74e84: Layer already exists
# 5a63f0a64b99: Layer already exists
# ebfd6e54712b: Layer already exists
# cfd97667b73b: Layer already exists
# dda643f89a6b: Layer already exists
# 06f4d263b25f: Layer already exists
# 5ecae586bbba: Layer already exists
# eb66e810a3df: Layer already exists
# 081c0f822cac: Layer already exists
# 0be4c2d28ad7: Layer already exists
# 40a154bd3352: Layer already exists
# latest: digest: sha256:f305c305b99c459ccd9a17f2a6a454150649fa9241ea9ee2a9f2751e6a5d9106 size: 4307
# 2022/03/12 08:27:55 Successfully pushed image: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io/azureml/azureml_7916fddb75e302f762445cdbd35af3f2:latest
# 2022/03/12 08:27:55 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 103.987708)
# 2022/03/12 08:27:55 Populating digests for step ID: acb_step_0...
# 2022/03/12 08:27:56 Successfully populated digests for step ID: acb_step_0
# 2022/03/12 08:27:56 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 97.314004)
# 2022/03/12 08:27:56 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.090912)
# 2022/03/12 08:27:56 The following dependencies were found:
# 2022/03/12 08:27:56
# - image:
#     registry: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io
#     repository: azureml/azureml_7916fddb75e302f762445cdbd35af3f2
#     tag: latest
#     digest: sha256:f305c305b99c459ccd9a17f2a6a454150649fa9241ea9ee2a9f2751e6a5d9106
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220113.v1
#     digest: sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
#   git: {}
# - image:
#     registry: b7697f56f94b4e839c4e46b96d210dcb.azurecr.io
#     repository: azureml/azureml_7916fddb75e302f762445cdbd35af3f2
#     tag: "1"
#     digest: sha256:f305c305b99c459ccd9a17f2a6a454150649fa9241ea9ee2a9f2751e6a5d9106
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220113.v1
#     digest: sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
#   git: {}
#
# Run ID: ds5 was successful after 3m26s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_1e3c3ee866e627473a68f2f09a0b4d493bc5a287d566d7d31017506407c5baa9_d.txt
# ========================================================================================================================
# 2022-03-12T08:34:54Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24747 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2022-03-12T08:34:54Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/mounts/workspaceblobstore -- stdout/stderr:
# 2022-03-12T08:34:54Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-03-12T08:34:54Z Starting output-watcher...
# 2022-03-12T08:34:54Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_f7dca5f5f0dac270c156fcb7f532f287
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 9e003623bee8: Pulling fs layer
# 3bc226f3e817: Pulling fs layer
# 0f1427a1ad9a: Pulling fs layer
# d3e37e76c9a7: Pulling fs layer
# 97329cd6cca4: Pulling fs layer
# 9fc8fd4f5d56: Pulling fs layer
# b7455bac32aa: Pulling fs layer
# 63561bab5267: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 9e003623bee8: Waiting
# 3bc226f3e817: Waiting
# 0f1427a1ad9a: Waiting
# d3e37e76c9a7: Waiting
# 97329cd6cca4: Waiting
# 9fc8fd4f5d56: Waiting
# b7455bac32aa: Waiting
# 63561bab5267: Waiting
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 9e003623bee8: Verifying Checksum
# 9e003623bee8: Download complete
# 0f1427a1ad9a: Verifying Checksum
# 0f1427a1ad9a: Download complete
# d3e37e76c9a7: Verifying Checksum
# d3e37e76c9a7: Download complete
# 97329cd6cca4: Verifying Checksum
# 97329cd6cca4: Download complete
# 9fc8fd4f5d56: Verifying Checksum
# 9fc8fd4f5d56: Download complete
# b7455bac32aa: Verifying Checksum
# b7455bac32aa: Download complete
# 63561bab5267: Verifying Checksum
# 63561bab5267: Download complete
# 3bc226f3e817: Verifying Checksum
# 3bc226f3e817: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 9e003623bee8: Pull complete
# 3bc226f3e817: Pull complete
# 0f1427a1ad9a: Pull complete
# d3e37e76c9a7: Pull complete
# 97329cd6cca4: Pull complete
# 9fc8fd4f5d56: Pull complete
# b7455bac32aa: Pull complete
# 63561bab5267: Pull complete
# Digest: sha256:1ba0fe158be6cf30393d682a14b245ddcb6727074eec0217cedc80252795e38b
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_f7dca5f5f0dac270c156fcb7f532f287:latest
# viennaglobal.azurecr.io/azureml/azureml_f7dca5f5f0dac270c156fcb7f532f287:latest
# 2022-03-12T08:35:25Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-03-12T08:35:25Z Check if container 88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a_DataSidecar already exist exited with 0,
#
# 6d4ee993ad6229c637f9e288ae8a688a73db4d0fee03714f7f88ff9f33d55234
# 2022-03-12T08:35:25Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2022-03-12T08:35:25Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-51bb4897eacfe3000fea4a00b8367a46-3a4c69566515cf68-01 -sshRequired=false]
# 2022/03/12 08:35:25 Didn't get JobInfoJson from env, now read from file
# 2022/03/12 08:35:25 Suceeded read JobInfoJson from file
# 2022/03/12 08:35:25 Starting App Insight Logger for task:  containerSetup
# 2022/03/12 08:35:25 Version: 3.0.01880.0001 Branch: 20220224.1 Commit: c67ee0d
# 2022/03/12 08:35:25 Entered ContainerSetupTask - Preparing infiniband
# 2022/03/12 08:35:25 Starting infiniband setup
# 2022/03/12 08:35:25 Python Version found is Python 3.7.9
#
# 2022/03/12 08:35:25 Returning Python Version as 3.7
# 2022/03/12 08:35:25 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/03/12 08:35:25 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022-03-12T08:35:25Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/03/12 08:35:25 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2022-03-12T08:35:25Z Not setting up Infiniband in Container
# 2022/03/12 08:35:25 Not setting up Infiniband in Container
# 2022/03/12 08:35:25 Not setting up Infiniband in Container
# 2022/03/12 08:35:25 Python Version found is Python 3.7.9
#
# 2022/03/12 08:35:25 Returning Python Version as 3.7
# 2022/03/12 08:35:25 sshd inside container not required for job, skipping setup.
# 2022/03/12 08:35:26 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2022/03/12 08:35:26 App Insight Client has already been closed
# 2022/03/12 08:35:26 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2022-03-12T08:35:26Z Starting docker container succeeded.
# 2022-03-12T08:35:26Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/65_job_prep-tvmps_2992f8bd246f19662ecdc8ff70eb4d42dd7ff0884815cb3c29b38083ac781c67_d.txt
# ===============================================================================================================
# [2022-03-12T08:35:28.039978] Entering job preparation.
# [2022-03-12T08:35:28.539830] Starting job preparation.
# [2022-03-12T08:35:28.539861] Extracting the control code.
# [2022-03-12T08:35:28.540326] Starting extract_project.
# [2022-03-12T08:35:28.540384] Starting to extract zip file.
# [2022-03-12T08:35:28.557415] Finished extracting zip file.
# [2022-03-12T08:35:28.560552] Using urllib.request Python 3.0 or later
# [2022-03-12T08:35:28.560590] Start fetching snapshots.
# [2022-03-12T08:35:28.560623] Start fetching snapshot.
# Starting the daemon thread to refresh tokens in background for process with pid = 54
# [2022-03-12T08:35:28.797341] Finished fetching snapshot.
# [2022-03-12T08:35:28.797374] Start fetching snapshot.
# [2022-03-12T08:35:33.745998] Finished fetching snapshot.
# [2022-03-12T08:35:33.746047] Finished fetching snapshots.
# [2022-03-12T08:35:33.746141] Finished extract_project.
# [2022-03-12T08:35:33.746266] Finished fetching and extracting the control code.
# [2022-03-12T08:35:33.751922] Start run_history_prep.
# [2022-03-12T08:35:33.758388] Job preparation is complete.
# [2022-03-12T08:35:33.758604] Entering Data Context Managers in Sidecar
# [2022-03-12T08:35:33.764197] Running Sidecar prep cmd...
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.22.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.22')).
# [2022-03-12T08:35:34.062530] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a
# [2022-03-12T08:35:34.063209] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2022-03-12T08:35:34.223] Enter __enter__ of DatasetContextManager
# [2022-03-12T08:35:34.224] SDK version: azureml-core==1.38.0.post2 azureml-dataprep==2.27.0. Session id: 2da6a974-ab33-4193-8fd9-9508fd33ab1f. Run id: 88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a.
# [2022-03-12T08:35:34.224] Processing 'diabetes_batch'.
# [2022-03-12T08:35:34.224] Mode: 'mount'.
# [2022-03-12T08:35:34.224] Path on compute is specified: 'False'.
# [2022-03-12T08:35:36.219] Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "c9da90d3-186f-4186-adfd-55fd6f487df2",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='fitta-project', subscription_id='f0ec0447-a406-4c0a-922d-f468c99bce13', resource_group='defaultresourcegroup-usw3')"
#   }
# }
# [2022-03-12T08:35:38.982] Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2 as folder.
# [2022-03-12T08:35:38.982] Processing 'inferences'.
# [2022-03-12T08:35:38.982] Mode: 'mount'.
# [2022-03-12T08:35:38.982] Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore'.
# [2022-03-12T08:35:39.116] Mounting inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore
# [2022-03-12T08:35:39.116] Output is not a single file
# [2022-03-12T08:35:39.117] Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore as folder
# [2022-03-12T08:35:39.810] Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2.
# [2022-03-12T08:35:40.813] Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2.
# [2022-03-12T08:35:40.813] Mounting inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.22.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.22')).
# [2022-03-12T08:35:43.862] Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore.
# [2022-03-12T08:35:43.918] Exit __enter__ of DatasetContextManager
# uri entered in sidecar: None
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2
# Set OutputDataset inferences's target path to /mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore
# [2022-03-12T08:35:43.919397] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2022-03-12T08:35:44.332480] Ran Sidecar prep cmd.
# [2022-03-12T08:35:44.332908] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/65_job_prep-tvmps_1e3c3ee866e627473a68f2f09a0b4d493bc5a287d566d7d31017506407c5baa9_d.txt
# ===============================================================================================================
# [2022-03-12T08:35:27.996504] Entering job preparation.
# [2022-03-12T08:35:28.489428] Starting job preparation.
# [2022-03-12T08:35:28.489480] Extracting the control code.
# [2022-03-12T08:35:28.489956] Starting extract_project.
# [2022-03-12T08:35:28.490025] Starting to extract zip file.
# [2022-03-12T08:35:28.504086] Finished extracting zip file.
# [2022-03-12T08:35:28.507199] Using urllib.request Python 3.0 or later
# [2022-03-12T08:35:28.507236] Start fetching snapshots.
# [2022-03-12T08:35:28.507266] Start fetching snapshot.
# Starting the daemon thread to refresh tokens in background for process with pid = 58
# [2022-03-12T08:35:28.803423] Finished fetching snapshot.
# [2022-03-12T08:35:28.803459] Start fetching snapshot.
# [2022-03-12T08:35:33.629249] Finished fetching snapshot.
# [2022-03-12T08:35:33.629287] Finished fetching snapshots.
# [2022-03-12T08:35:33.629385] Finished extract_project.
# [2022-03-12T08:35:33.629480] Finished fetching and extracting the control code.
# [2022-03-12T08:35:33.635135] Start run_history_prep.
# [2022-03-12T08:35:33.641617] Job preparation is complete.
# [2022-03-12T08:35:33.641859] Entering Data Context Managers in Sidecar
# [2022-03-12T08:35:33.646605] Running Sidecar prep cmd...
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.22.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.22')).
# [2022-03-12T08:35:33.915931] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a
# [2022-03-12T08:35:33.916619] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2022-03-12T08:35:34.073] Enter __enter__ of DatasetContextManager
# [2022-03-12T08:35:34.076] SDK version: azureml-core==1.38.0.post2 azureml-dataprep==2.27.0. Session id: b80026c8-a6dd-454d-9e6b-cea0d4bc84b7. Run id: 88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a.
# [2022-03-12T08:35:34.076] Processing 'diabetes_batch'.
# [2022-03-12T08:35:34.076] Mode: 'mount'.
# [2022-03-12T08:35:34.076] Path on compute is specified: 'False'.
# [2022-03-12T08:35:36.356] Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
# ...
# [2022-03-12T08:36:28.802715] Entering context manager injector.
# [2022-03-12T08:36:29.282802] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.38.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2022-03-12T08:36:29.286406] Entering Run History Context Manager.
# [2022-03-12T08:36:29.958736] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a
# [2022-03-12T08:36:29.958773] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.38.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'diabetes_batch']
# [2022-03-12T08:36:29.958794] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.38.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore', '--input_fds_0', 'diabetes_batch']
#
# 2022/03/12 08:36:33 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_2992f8bd246f19662ecdc8ff70eb4d42dd7ff0884815cb3c29b38083ac781c67_d.txt
# ===============================================================================================================
# [2022-03-12T08:37:27.874294] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.22.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.22')).
# [2022-03-12T08:37:28.542776] Starting job release
# [2022-03-12T08:37:28.543267] Logging experiment finalizing status in history service.
# [2022-03-12T08:37:28.543763] job release stage : upload_datastore starting...Starting the daemon thread to refresh tokens in background for process with pid = 346
#
# [2022-03-12T08:37:28.544248] job release stage : start importing azureml.history._tracking in run_history_release.
# [2022-03-12T08:37:28.549031] Entering context manager injector.
# [2022-03-12T08:37:28.548973] job release stage : execute_job_release starting...[2022-03-12T08:37:28.558103] job release stage : upload_datastore completed...[2022-03-12T08:37:28.558261] job release stage : copy_batchai_cached_logs starting...
#
#
# [2022-03-12T08:37:28.559584] job release stage : copy_batchai_cached_logs completed...
# [2022-03-12T08:37:28.636613] job release stage : send_run_telemetry starting...
# [2022-03-12T08:37:28.664761] get vm size and vm region successfully.
# [2022-03-12T08:37:28.676039] get compute meta data successfully.
# [2022-03-12T08:37:28.724888] job release stage : execute_job_release completed...
# [2022-03-12T08:37:28.809500] post artifact meta request successfully.
# [2022-03-12T08:37:28.838666] upload compute record artifact successfully.
# [2022-03-12T08:37:28.838822] job release stage : send_run_telemetry completed...
# [2022-03-12T08:37:28.839196] Running in AzureML-Sidecar, starting to exit user context managers...
# [2022-03-12T08:37:28.839462] Running Sidecar release cmd...
# [2022-03-12T08:37:28.849301] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a
# [2022-03-12T08:37:28.865] Enter __exit__ of DatasetContextManager
# [2022-03-12T08:37:28.865] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2.
# [2022-03-12T08:37:29.871] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2.
# [2022-03-12T08:37:29.872] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore.
# [2022-03-12T08:37:29.885] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore.
# [2022-03-12T08:37:29.885] Exit __exit__ of DatasetContextManager
# [2022-03-12T08:37:29.885318] Removing absolute paths from host...
# [2022-03-12T08:37:29.885557] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2022-03-12T08:37:30.400857] Ran Sidecar release cmd.
# [2022-03-12T08:37:30.401014] Job release is complete
#
# Streaming azureml-logs/75_job_post-tvmps_1e3c3ee866e627473a68f2f09a0b4d493bc5a287d566d7d31017506407c5baa9_d.txt
# ===============================================================================================================
# [2022-03-12T08:37:28.408347] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.22.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.22')).
# [2022-03-12T08:37:28.971536] job release stage : copy_batchai_cached_logs starting...
# [2022-03-12T08:37:28.971650] job release stage : copy_batchai_cached_logs completed...
# [2022-03-12T08:37:28.971728] Running in AzureML-Sidecar, starting to exit user context managers...
# [2022-03-12T08:37:28.972131] Running Sidecar release cmd...
# [2022-03-12T08:37:28.980379] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a
# [2022-03-12T08:37:28.998] Enter __exit__ of DatasetContextManager
# [2022-03-12T08:37:28.998] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2.
# [2022-03-12T08:37:30.006] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/diabetes_batch_c9da90d3-186f-4186-adfd-55fd6f487df2.
# [2022-03-12T08:37:30.006] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore: Invalid argument
# [2022-03-12T08:37:30.022] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/fitta-project/azureml/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/wd/inferences_workspaceblobstore.
# [2022-03-12T08:37:30.022] Exit __exit__ of DatasetContextManager
# [2022-03-12T08:37:30.022347] Removing absolute paths from host...
# [2022-03-12T08:37:30.022618] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2022-03-12T08:37:30.679132] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-03-12T08:34:50.398538Z', 'endTimeUtc': '2022-03-12T08:37:41.701702Z', 'services': {}, 'properties': {'ContentSnapshotId': '0495a42d-c3bf-4bb6-94cb-aac4081a15fd', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '4861cc92-c165-4083-9b8d-b94debf7de4f', 'azureml.moduleName': 'batch-score-diabetes', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'db8fc392', 'azureml.pipelinerunid': '4d3bc33b-0b37-4a97-801c-9a012ebfe59c', 'azureml.pipeline': '4d3bc33b-0b37-4a97-801c-9a012ebfe59c', 'azureml.pipelineComponent': 'masterescloud', 'azureml.parallelrunstep': 'true', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'c9da90d3-186f-4186-adfd-55fd6f487df2'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': 'a1926601-d35a-4807-ae76-3867396bcc7b'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/88f3fec2-3c70-4b7d-abed-e10a0f1d9d2a/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "a1926601-d35a-4807-ae76-3867396bcc7b",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='fitta-project', subscription_id='f0ec0447-a406-4c0a-922d-f468c99bce13', resource_group='defaultresourcegroup-usw3')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.38.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'your-compute-cluster', 'dataReferences': {}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': 'c9da90d3-186f-4186-adfd-55fd6f487df2', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': '4d3bc33b-0b37-4a97-801c-9a012ebfe59c', 'azureml.pipelineRun.moduleNodeId': 'db8fc392', 'azureml.pipelineRun.outputPortName': 'inferences'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2022-03-12T08:24:25Z_bf8477f8', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults']}], 'name': 'azureml_e220b045f6c3c3008b1a386af067185d'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applica ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '4d3bc33b-0b37-4a97-801c-9a012ebfe59c', 'status': 'Completed', 'startTimeUtc': '2022-03-12T08:23:48.307963Z', 'endTimeUtc': '2022-03-12T08:37:44.169437Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://fittaproject2060775278.blob.core.windows.net/azureml/ExperimentRun/dcid.4d3bc33b-0b37-4a97-801c-9a012ebfe59c/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=9QrNLOoM1DUwE3nqRqOOkuqji09zx5gRuhlzxWW1qBc%3D&skoid=5a442350-2e66-4ab5-849c-ae5fe24b45a2&sktid=f94bf4d9-8097-4794-adf6-a5466ca28563&skt=2022-03-12T02%3A08%3A30Z&ske=2022-03-13T10%3A18%3A30Z&sks=b&skv=2019-07-07&st=2022-03-12T08%3A27%3A45Z&se=2022-03-12T16%3A37%3A45Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://fittaproject2060775278.blob.core.windows.net/azureml/ExperimentRun/dcid.4d3bc33b-0b37-4a97-801c-9a012ebfe59c/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=tRBvoFus3ftr8%2FrzGj0BC41W1IH%2F%2FB6e%2Bhgic9i8Yq4%3D&skoid=5a442350-2e66-4ab5-849c-ae5fe24b45a2&sktid=f94bf4d9-8097-4794-adf6-a5466ca28563&skt=2022-03-12T02%3A08%3A30Z&ske=2022-03-13T10%3A18%3A30Z&sks=b&skv=2019-07-07&st=2022-03-12T08%3A27%3A45Z&se=2022-03-12T16%3A37%3A45Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://fittaproject2060775278.blob.core.windows.net/azureml/ExperimentRun/dcid.4d3bc33b-0b37-4a97-801c-9a012ebfe59c/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=SzPT9w8uU5L%2Bprvp9%2FSgucfLbTnwUO1QCmYHrBQkrIQ%3D&skoid=5a442350-2e66-4ab5-849c-ae5fe24b45a2&sktid=f94bf4d9-8097-4794-adf6-a5466ca28563&skt=2022-03-12T02%3A08%3A30Z&ske=2022-03-13T10%3A18%3A30Z&sks=b&skv=2019-07-07&st=2022-03-12T08%3A27%3A45Z&se=2022-03-12T16%3A37%3A45Z&sp=r'}, 'submittedBy': 'JOSE EMANUEL RODRIGUEZ FITTA'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           1
# 5    13.csv           0
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           1
# 9    17.csv           0
# 10   18.csv           1
# 11   19.csv           1
# 12    2.csv           0
# 13   20.csv           1
# 14   21.csv           0
# 15   22.csv           0
# 16   23.csv           0
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 9dcc4f00-0ecf-4f6d-8b54-ab068801470d,
# Status: Active,
# Endpoint: https://westus3.api.azureml.ms/pipelines/v1.0/subscriptions/f0ec0447-a406-4c0a-922d-f468c99bce13/resourceGroups/defaultresourcegroup-usw3/providers/Microsoft.MachineLearningServices/workspaces/fitta-project/PipelineRuns/PipelineSubmit/9dcc4f00-0ecf-4f6d-8b54-ab068801470d)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westus3.api.azureml.ms/pipelines/v1.0/subscriptions/f0ec0447-a406-4c0a-922d-f468c99bce13/resourceGroups/defaultresourcegroup-usw3/providers/Microsoft.MachineLearningServices/workspaces/fitta-project/PipelineRuns/PipelineSubmit/9dcc4f00-0ecf-4f6d-8b54-ab068801470d

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c?wsid=/subscriptions/f0ec0447-a406-4c0a-922d-f468c99bce13/resourcegroups/defaultresourcegroup-usw3/workspaces/fitta-project&tid=f94bf4d9-8097-4794-adf6-a5466ca28563
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c', 'status': 'Completed', 'startTimeUtc': '2022-03-12T08:41:01.008856Z', 'endTimeUtc': '2022-03-12T08:41:04.682254Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelineid': '9dcc4f00-0ecf-4f6d-8b54-ab068801470d'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://fittaproject2060775278.blob.core.windows.net/azureml/ExperimentRun/dcid.0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=sAY3%2FxAyJaMw8tQTVmU%2BEdF9dIbFgq0Z%2FBUpaxpMo38%3D&skoid=5a442350-2e66-4ab5-849c-ae5fe24b45a2&sktid=f94bf4d9-8097-4794-adf6-a5466ca28563&skt=2022-03-12T02%3A08%3A30Z&ske=2022-03-13T10%3A18%3A30Z&sks=b&skv=2019-07-07&st=2022-03-12T08%3A31%3A05Z&se=2022-03-12T16%3A41%3A05Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://fittaproject2060775278.blob.core.windows.net/azureml/ExperimentRun/dcid.0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Gax3Sxxy5Ey1qSfuKeCMCH3cF%2BjZv1Pis6ye0nL8BJU%3D&skoid=5a442350-2e66-4ab5-849c-ae5fe24b45a2&sktid=f94bf4d9-8097-4794-adf6-a5466ca28563&skt=2022-03-12T02%3A08%3A30Z&ske=2022-03-13T10%3A18%3A30Z&sks=b&skv=2019-07-07&st=2022-03-12T08%3A31%3A05Z&se=2022-03-12T16%3A41%3A05Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://fittaproject2060775278.blob.core.windows.net/azureml/ExperimentRun/dcid.0cf24f6b-6c46-44a7-8ac5-a2c8df5b560c/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=%2B0efGXYUk6GCd2XcHKWQ6m2CoTUrY3dWi4jkAVE2%2B4E%3D&skoid=5a442350-2e66-4ab5-849c-ae5fe24b45a2&sktid=f94bf4d9-8097-4794-adf6-a5466ca28563&skt=2022-03-12T02%3A08%3A30Z&ske=2022-03-13T10%3A18%3A30Z&sks=b&skv=2019-07-07&st=2022-03-12T08%3A31%3A05Z&se=2022-03-12T16%3A41%3A05Z&sp=r'}, 'submittedBy': 'JOSE EMANUEL RODRIGUEZ FITTA'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           1
# 5    13.csv           0
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           1
# 9    17.csv           0
# 10   18.csv           1
# 11   19.csv           1
# 12    2.csv           0
# 13   20.csv           1
# 14   21.csv           0
# 15   22.csv           0
# 16   23.csv           0
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
